# %% [markdown]
# # 00 — Setup (run once, then throw away)
#
# Creates the Drive folder, configures git, connects this repo to GitHub, and makes the first commit. This is the **one-time setup notebook** — once your repo is live and the first commit is pushed, you don't need it again.
#
# **Before you start:** create an **empty** repo on github.com named `iot-trust-compression` (no README / licence / .gitignore — this bundle already has all three), and have a Personal Access Token ready (GitHub → Settings → Developer settings → Tokens → Generate, scope `repo`). It looks like `ghp_...`.
#
# Then upload `iot-trust-compression.zip` to this Colab session (Files panel → upload), and run the cells below in order.

# %% [markdown]
# ## 1. Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 2. Unzip the bundle into Drive
#
# Puts the repo at `MyDrive/IoT_Trust_Research/iot-trust-compression/` — the exact path the notebooks' bootstrap cell expects.

# %%
import os, zipfile

PROJECT_DIR = '/content/drive/MyDrive/IoT_Trust_Research'
os.makedirs(PROJECT_DIR, exist_ok=True)

# expects iot-trust-compression.zip uploaded to the Colab session root (/content)
ZIP = '/content/iot-trust-compression.zip'
with zipfile.ZipFile(ZIP) as z:
    z.extractall(PROJECT_DIR)

REPO = f'{PROJECT_DIR}/iot-trust-compression'
os.chdir(REPO)
print('Repo at:', os.getcwd())
# !ls -la

# %% [markdown]
# ## 3. Configure git identity
#
# **Replace the email** with the one on your GitHub account.

# %%
# !git config --global user.name "Md Anas Biswas"
# !git config --global user.email "up2082724@myport.ac.uk"   # <- your GitHub email

# %% [markdown]
# ## 4. Initialise the repo and connect to GitHub
#
# **Replace `YOUR_TOKEN`** with your `ghp_...` token. The token is used once to set the remote, then we scrub it from the cell in step 7 so it never sits in a saved notebook.

# %%
GITHUB_USERNAME = "anasbiswas1"
GITHUB_TOKEN    = "YOUR_TOKEN"          # the ghp_... token
REPO_NAME       = "iot-trust-compression"

# !git init -q
# !git branch -M main
# !git remote remove origin 2>/dev/null
# !git remote add origin https://{GITHUB_USERNAME}:{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{REPO_NAME}.git
print("remote set")

# %% [markdown]
# ## 5. Sanity check — confirm data/ and models/ are ignored
#
# These must NOT go to GitHub (they live in Drive). `git status` should show the code, notebooks, `config/`, `src/`, `results/`, `logs/`, `PLAN.md`, `README.md` — but **not** `data/` or `models/`.

# %%
# !git add -A --dry-run | grep -E 'data/|models/' && echo '!!! data/models would be committed — check .gitignore' || echo 'OK: data/ and models/ correctly ignored'

# %% [markdown]
# ## 6. First commit + push

# %%
# !git add -A
# !git commit -q -m "Initial commit: iot-trust-compression scaffold (config-driven paths, src modules, stage notebooks, frozen prereg)"
# !git push -u origin main
print("pushed — refresh your GitHub repo to confirm")

# %% [markdown]
# ## 7. Scrub the token (IMPORTANT)
#
# Re-run step 4's cell with `GITHUB_TOKEN = "REDACTED"` (the remote is already set, so the real token is no longer needed), then **File → Save**. Now delete this whole setup notebook — you won't need it again. From here on, the per-notebook end-of-unit ritual (`git add -A && git commit && git push`) is all you use.

# %%
# After running, set GITHUB_TOKEN = "REDACTED" in step 4 and re-run that cell, then delete this notebook.
print("Setup done. Drive + GitHub are connected. Open notebooks/00_data_prep_and_split_audit.ipynb next.")
