# %% [markdown]
# # 04 — Crux Probe
#
# THE SPINE (D1). Linear-probe recoverability + margin: did compression REMOVE rare-class information, or just MOVE the boundary? Pre-committed to a GRADED, class-dependent answer. **Branch point** — sets the FORM of Stage 4.

# %%
# --- Colab bootstrap (config-driven; never hardcode a path) ---
try:
    from google.colab import drive; drive.mount('/content/drive')
    REPO = '/content/drive/MyDrive/IoT_Trust_Research/iot-trust-compression'
except Exception:
    REPO = '.'
import os, sys
os.chdir(REPO); sys.path.insert(0, REPO)
from src.config import CFG, PATHS, set_all_seeds, require_frozen
set_all_seeds(CFG['anchor_seed'])

# %%
# Computes trust metrics — refuse to run until the prereg is frozen.
require_frozen()

# %% [markdown]
# ## Probe recoverability: anchor vs compressed features
#
# Run under the grouped split (a probe on leakage-trained features fakes 'information survived').

# %%
from src import crux
# res = crux.probe_recoverability(feats_anchor, feats_comp, labels)
# report per-class AUC retention on a CONTINUUM; flag vs config.crux.auc_retention_threshold

# %% [markdown]
# ## Branch decision
#
# Information survived -> decision-layer mitigation. Information lost -> compression-time mitigation. Expect a mix — record which classes fall where.

# %%
# summarise per-class survived vs lost; this drives notebook 07

# %% [markdown]
# ## End-of-unit (non-negotiable)

# %%
# --- End-of-unit discipline (run before moving on) ---
# 1) outputs saved to Drive  2) commit + push  3) push CSVs/figures  4) confirm sync
# !cd $REPO && git add -A && git commit -m 'nb04: <meaningful message>' && git push
print('Saved under:', PATHS.tables().parent)
